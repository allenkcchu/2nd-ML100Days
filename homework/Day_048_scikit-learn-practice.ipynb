# %% [markdown]
# # Kaggle competition:  scikit-learn-practice
# ![snapshot](image/Day_048_HW.JPG)

# %%
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import r2_score, accuracy_score

dir_data = './data/data-science-london-scikit-learn/'
trainData = os.path.join(dir_data, 'train.csv')
trainTarget = os.path.join(dir_data, 'trainLabels.csv')

data = np.array(pd.read_csv(trainData))
target = np.array(pd.read_csv(trainTarget))
[x_train,x_test,y_train,y_test] = train_test_split(data,target.ravel(),test_size=0.25,random_state=43)

# %%
n_estimators = [100,200,300,400,500]
max_depth = [1,2,3,4,5]
learning_rate = [0.1,1,10,100,1000]
# subsample = 1-np.arange(0,1,0.1)
param_grid = dict(n_estimators = n_estimators, 
                  learning_rate = learning_rate, 
                  max_depth = max_depth)
grid_search = GridSearchCV(GradientBoostingClassifier(), param_grid, 
                                 scoring='neg_log_loss', n_jobs=-1, verbose=1, cv=5)
grid_result = grid_search.fit(x_train,y_train)
print('Best Accuracy: %.3f using %s' % (grid_result.best_score_, grid_result.best_params_))
clf = GradientBoostingClassifier(n_estimators = grid_result.best_params_['n_estimators'], 
                                 max_depth = grid_result.best_params_['max_depth'], 
                                 learning_rate = grid_result.best_params_['learning_rate'])
clf.fit(x_train,y_train)
y_pred = clf.predict(x_test)
result = accuracy_score(y_test,y_pred)
print('Accuracy score of this regrssion problem is %.3f' % (result))
# Out:
# Fitting 5 folds for each of 125 candidates, totalling 625 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   13.4s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 625 out of 625 | elapsed:  5.0min finished
# Best Accuracy: -0.312 using {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 100}
# Accuracy score of this regrssion problem is 0.916

# %%
test = os.path.join(dir_data, 'test.csv')
testData = pd.read_csv(test,header=None)
result = clf.predict(testData)
testData.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  2.808909 -0.242894 -0.546421  0.255162  1.749736 -0.030458 -1.322071
# 1 -0.374101  0.537669  0.081063  0.756773  0.915231  2.557282  3.703187
# 2 -0.088370  0.154743  0.380716 -1.176126  1.699867 -0.258627 -1.384999
# 3 -0.685635  0.501283  1.873375  0.215224 -3.983468 -0.103637  4.136113
# 4  0.350867  0.721897 -0.477104 -1.748776 -2.627405  1.075433  4.954253
#
#          7         8         9     ...           30        31        32  \
# 0  3.578071 -0.667578 -0.884257    ...    -0.261688 -0.224375 -1.675606
# 1  1.673835 -0.764122 -1.228040    ...    -0.969463  0.574154 -2.200519
# 2  1.093584  1.596633  0.230631    ...    -0.769885 -0.005143  1.467490
# 3 -0.225431 -1.515015 -1.071763    ...     0.968609  2.386412 -0.131219
# 4 -3.293501 -0.760369  0.204360    ...     0.260553 -2.045650 -2.173227
#
#          33        34        35        36        37        38        39
# ...

# %%
df = pd.DataFrame({'Id':testData.index+1, 
                   'Solution':result})
df.to_csv('test1.csv',index=False)
df.head()
# Out:
#    Id  Solution
# 0   1         1
# 1   2         0
# 2   3         0
# 3   4         0
# 4   5         0
